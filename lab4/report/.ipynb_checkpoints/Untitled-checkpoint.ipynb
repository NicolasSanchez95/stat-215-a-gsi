# %%
from scipy.special import erfinv, erf

from scipy.stats import norm
import numpy as np
import scipy.stats as stats
dist = stats.norm(0, 1)

# %%
x_05 =dist.ppf(1.-0.025)
x_01 = dist.ppf(1.-0.005)
x_005 = dist.ppf(1.-0.0025)
x_001= dist.ppf(1.-0.0005)

x = np.array([x_05, x_01, x_005, x_001])
# Out:
# array([1.95996398, 2.5758293 , 2.80703377, 3.29052673])

# %%
pd.DataFrame(columns = ['p=0.05','p=0.01', 'p=0.005', 'p=0.001' ])
# Out:
# np.float64(0.025000000000000022)

# %%
pi_start_post = 1/(1+np.exp(0.5*x**2))
pi_start_post_N = (x)/(x+ np.exp(0.5*(x**2-1)))
pi_start_post_N
# Out:
# array([0.32130014, 0.13339406, 0.08259568, 0.02359747])

# %%
pi_start_post
# Out:
# array([0.12778025, 0.03497744, 0.01908245, 0.004435  ])
